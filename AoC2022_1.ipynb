# %%
# ownerproof-2800342-1670637093-85827f7be479

# Mount Google Drive THEN cd to working directory
from google.colab import drive
drive.mount('/content/drive/')

# cd to drive/ColabFiles
# %cd 'drive/MyDrive/ColabFiles'

# Elfs Input
elf_calories = '''

'''

#print(elf_calories)
# !pwd
# !ls

# Read text file
#get file object
elf_dict = {}
x = 1
y = []

with open("AoC2022-1.txt") as f:
  for line in f:
    print(line)
    if line == '\n':
      y_sum = sum(y)
      elf_dict.update({x_name: y_sum})
      x += 1
      y = []
    else:
      xname = str(x)
      x_name = f'elf_{xname}'
      y.append(int(line))
     
	#if line is empty, you are done with all lines in the file
#  if not line:
#    break
	#you can access the line
  #print(line.strip())

#close file
f.close

fin_max = max(elf_dict, key=elf_dict.get)
print("Maximum value:",fin_max)
print(elf_dict[fin_max])


# Lets pop out the max elf to find the next max then the next max
remove_max_elf1 = elf_dict.pop(fin_max)

# Find max with top elf gone
fin_max = max(elf_dict, key=elf_dict.get)
print("Maximum value:",fin_max)
print(elf_dict[fin_max])

# Lets pop out the max elf to find the next max then the next max
remove_max_elf2 = elf_dict.pop(fin_max)

# Find max with top elf gone
fin_max = max(elf_dict, key=elf_dict.get)
print("Maximum value:",fin_max)
print(elf_dict[fin_max])


# Lets pop out the max elf to find the next max then the next max
remove_max_elf3 = elf_dict.pop(fin_max)

top3 = remove_max_elf3 + remove_max_elf1 + remove_max_elf2
print(f'top 3 elves total = {top3}')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/ColabFiles'
# /content/drive/MyDrive/ColabFiles
# /content/drive/My Drive/ColabFiles
# AoC2022-1.txt
# 4323
#
# 4004
#
# 4070
#
# 1780
#
# 5899
#
# 1912
#
# 2796
#
# 5743
#
# 3008
#
# 1703
#
# 4870
#
# 5048
#
# 2485
#
# 1204
#
#
#
# 30180
#
#
#
# 33734
#
# 19662
#
#
#
# 2402
#
# 4395
#
# 2703
#
# 1562
#
# 2407
#
# 3393
#
# 4311
#
# 1314
#
# 2729
#
# 2225
#
# 4420
#
# 4136
#
# 2867
#
# 1032
#
# 2095
#
#
#
# 7366
#
# 3496
#
# 6177
#
# 1426
#
# 4750
#
# 2655
#
# 3194
#
# 4240
#
# 4024
#
# 3510
#
# 2606
#
# 2335
#
#
#
# 1524
#
# 17720
#
# 23749
#
#
#
# 2549
#
# 1945
#
# 3392
#
# 4965
#
# 5601
#
# 4725
#
# 1462
#
# 1470
#
# 2988
#
# 5339
#
# 1620
#
# 6098
#
# 4447
#
# 5115
#
# 4102
#
#
#
# 2729
#
# 4836
#
# 10723
#
# 6705
#
# 2278
#
# 3290
#
# 2735
#
# 1813
#
#
#
# 10285
#
# 2302
#
# 6970
#
# 10710
#
# ...
