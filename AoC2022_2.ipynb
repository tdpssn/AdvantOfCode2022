# %%
# ownerproof-2800342-1670637093-85827f7be479

# !pip install -Uqq ipdb
import ipdb

# Mount Google Drive THEN cd to working directory
from google.colab import drive
drive.mount('/content/drive/')


# cd to drive/ColabFiles
# %cd 'drive/MyDrive/ColabFiles'

score = 0
with open("AoC2022-2.txt") as f:
  for line in f:
    line = line.strip('\n')
    print(line)
    if line == 'A X':
      print('Rock ties Rock +4')
      score = score + 1 + 3
    if line == 'A Y':
      print('Rock loses Paper +8')
      score = score + 2 + 6
    if line == 'A Z':
      print('Rock wins Scissors +7')
      score = score + 3 + 0
    if line == "B X":
      print('Paper wins Rock +8')
      score = score + 1 + 0
    if line == "B Y":
      print('Paper ties Paper +5')
      score = score + 2 + 3
    if line == "B Z":
      print('Paper loses Scissors +2')
      score = score + 3 + 6
    if line == "C X":
      print('Scissors loses Rock +3')
      score = score + 1 + 6
    if line == "C Y":
      print('Scissors wins Paper +9')
      score = score + 2 + 0
    if line == "C Z":
      print('Scissors ties Scissors +6')
      score = score + 3 + 3
  
print(score)

'''
x = lose
y = tie
z = win
'''
# Part 2 just redo the win matrix
score = 0
with open("AoC2022-2.txt") as f:
  for line in f:
    line = line.strip('\n')
    print(line)
    if line == 'A X':
      print('Rock loses Scissors +3')
      score = score + 3 + 0
    if line == 'A Y':
      print('Rock ties Rock +8')
      score = score + 1 + 3
    if line == 'A Z':
      print('Rock wins Paper +7')
      score = score + 2 + 6
    if line == "B X":
      print('Paper loses Rock +1')
      score = score + 1 + 0
    if line == "B Y":
      print('Paper ties Paper +5')
      score = score + 2 + 3
    if line == "B Z":
      print('Paper loses Scissors +2')
      score = score + 3 + 6
    if line == "C X":
      print('Scissors loses Paper +3')
      score = score + 2 + 0
    if line == "C Y":
      print('Scissors ties Scissors +9')
      score = score + 3 + 3
    if line == "C Z":
      print('Scissors wins Rock +6')
      score = score + 1 + 6
  
print(score)
# Out:
# Streaming output truncated to the last 5000 lines.
# Paper ties Paper +5
# A Z
# Rock wins Paper +7
# A Z
# Rock wins Paper +7
# C Z
# Scissors wins Rock +6
# B Y
# Paper ties Paper +5
# B Y
# Paper ties Paper +5
# B X
# Paper loses Rock +1
# B Z
# Paper loses Scissors +2
# C Z
# Scissors wins Rock +6
# B X
# Paper loses Rock +1
# B Y
# Paper ties Paper +5
# A Z
# Rock wins Paper +7
# B Y
# Paper ties Paper +5
# B Z
# Paper loses Scissors +2
# B Y
# Paper ties Paper +5
# C Z
# Scissors wins Rock +6
# B Z
# Paper loses Scissors +2
# B Y
# Paper ties Paper +5
# B Z
# Paper loses Scissors +2
# C Y
# Scissors ties Scissors +9
# B Y
# Paper ties Paper +5
# A Z
# Rock wins Paper +7
# B Y
# Paper ties Paper +5
# B Y
# Paper ties Paper +5
# B Y
# Paper ties Paper +5
# C Y
# Scissors ties Scissors +9
# A Z
# Rock wins Paper +7
# B Y
# Paper ties Paper +5
# B X
# Paper loses Rock +1
# A Z
# Rock wins Paper +7
# B X
# Paper loses Rock +1
# A Z
# Rock wins Paper +7
# A Z
# Rock wins Paper +7
# ...
